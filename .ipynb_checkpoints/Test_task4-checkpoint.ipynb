# %%
import pandas as pd

df = pd.read_pickle('contracts_data.pkl')
pd.set_option('display.max_columns', 205)
pd.set_option('display.max_rows', 5)

# %%
products_df = df[['_regNum', 'products.product']]
products_df
# Out:
# {'sid': '283821141', 'guid': '566EDAFBD9E44804A69061C1EBB2D688', 'OKPD2': {'code': '21.20.10.225', 'name': 'Миорелаксанты'}, 'name': 'Эсмерон', 'type': 'PRODUCT', 'OKEI': {'code': '111', 'fullName': 'см[3*];^мл'}, 'price': '32.34800000000', 'priceRUR': '32.34800000000', 'quantity': '1000', 'sum': '32348.00', 'sumRUR': '32348.00', 'VATRate': '0', 'drugPurchaseObjectInfo': {'drugInfoUsingReferenceInfo': {'MNNsInfo': {'MNNInfo': {'MNNExternalCode': '1ee0fa82-bf5b-11e9-bd5d-bb9a4388d7fc', 'MNNDrugCode': '2764', 'MNNName': 'РОКУРОНИЯ БРОМИД', 'dosageUser': {'dosageUserOKEI': {'code': '111', 'fullName': 'см[3*];^мл'}, 'dosageUserName': 'мл'}, 'positionsTradeName': {'positionTradeName': [{'sid': '13301404', 'guid': 'E11DD84EED124D80AA668D453ED24E12', 'positionTradeNameExternalCode': '225d4cd8-bf5b-11e9-bd5d-7b1920d9adcb', 'drugCode': '21.20.10.225-000006-1-00017-2000000570216', 'tradeInfo': {'tradeName': 'Эсмерон'}, 'certificateNumber': 'П N012646/01', 'medicamentalFormInfo': {'medicamentalFormName': 'РАСТВОР ДЛЯ ВНУТРИВЕННОГО ВВЕДЕНИЯ'}, 'dosageInfo': {'dosageName': 'мг/мл', 'dosageOKEI': {'code': '111', 'nationalCode': 'см[3*];^мл', 'name': 'Кубический сантиметр;^миллилитр'}, 'dosageValue': '10', 'dosageGRLSValue': '10 мг/мл', 'dosageUserName': 'мл'}, 'certificateKeeperName': 'Н.В. ОРГАНОН', 'manufacturerInfo': {'manufacturerOKSM': {'countryCode': '528', 'countryFullName': 'Королевство Нидерландов'}, 'manufacturerName': 'Н.В. ОРГАНОН'}, 'packagingsInfo': {'packagingInfo': {'primaryPackagingInfo': {'primaryPackagingName': 'ФЛАКОН'}, 'packaging1Quantity': '5', 'packaging2Quantity': '10', 'sumaryPackagingQuantity': '50', 'completeness': '~', 'drugQuantity': '1000'}}, 'MNNNormName': 'РОКУРОНИЯ БРОМИД', 'dosageNormName': '10 мг/мл', 'medicamentalFormNormName': 'РАСТВОР ДЛЯ ВНУТРИВЕННОГО ВВЕДЕНИЯ'}]}}}, 'isZNVLP': 'false'}}}
#
# {'sid': '333089595', 'guid': 'D34B7389E46D4AC6B8BB7554DAC8E642', 'indexNum': '1', 'OKPD2': {'code': '21.20.10.214', 'name': 'Иммунодепрессанты'}, 'name': 'Актемра', 'hierarchyType': 'ND', 'type': 'PRODUCT', 'OKEI': {'code': '111', 'fullName': 'см[3*];^мл'}, 'price': '39012.00000000000', 'priceRUR': '39012.00000000000', 'quantity': '10', 'sum': '390120.00', 'sumRUR': '390120.00', 'VATRate': 'n', 'drugPurchaseObjectInfo': {'drugInfoUsingReferenceInfo': {'MNNsInfo': {'MNNInfo': {'MNNExternalCode': '1edb5550-bf5b-11e9-bd5d-6f2ebf3160dc', 'MNNDrugCode': '21.20.10.214-000029-1-00096-0000000000000', 'MNNName': 'ТОЦИЛИЗУМАБ', 'dosageUser': {'dosageUserOKEI': {'code': '111', 'fullName': 'см[3*];^мл'}, 'dosageUserName': 'мл'}, 'positionsTradeName': {'positionTradeName': [{'sid': '15498061', 'guid': '259E2FCC24854A1FB628B2B34564C428', 'positionTradeNameExternalCode': 'b29ac57c-4675-11ea-a8a4-3b70d47cd724', 'drugCode': '21.20.10.214-000029-1-00096-2000000751010', 'tradeInfo': {'tradeName': 'Актемра'}, 'certificateNumber': 'ЛСР-003012/09', 'medicamentalFormInfo': {'medicamentalFormName': 'КОНЦЕНТРАТ ДЛЯ ПРИГОТОВЛЕНИЯ РАСТВОРА ДЛЯ ИНФУЗИЙ'}, 'dosageInfo': {'dosageName': 'мг/мл', 'dosageOKEI': {'code': '111', 'nationalCode': 'см[3*];^мл', 'name': 'Кубический сантиметр;^миллилитр'}, 'dosageValue': '20', 'dosageGRLSValue': '20 мг/мл', 'dosageUserName': 'мл'}, 'certificateKeeperName': 'Ф. ХОФФМАНН-ЛЯ РОШ ЛТД.', 'manufacturerInfo': {'manufacturerOKSM': {'countryCode': '392', 'countryFullName': 'ЯПОНИЯ'}, 'manufacturerName': 'ЧУГАЙ ФАРМА МАНУФЕКТУРИНГ КО. ЛТД.'}, 'packagingsInfo': {'packagingInfo': {'primaryPackagingInfo': {'primaryPackagingName': 'ФЛАКОН'}, 'packaging1Quantity': '10', 'packaging2Quantity': '1', 'sumaryPackagingQuantity': '10', 'completeness': '~'}}, 'MNNNormName': 'ТОЦИЛИЗУМАБ', 'dosageNormName': '20 мг/мл', 'medicamentalFormNormName': 'КОНЦЕНТРАТ ДЛЯ ПРИГОТОВЛЕНИЯ РАСТВОРА ДЛЯ ИНФУЗИЙ'}]}}}, 'isZNVLP': 'false'}}}

# %%
def add_columns_from_dict(column_name, column_value_dict, new_row):
    for key, value in column_value_dict.items():
        if isinstance(value, dict):
            new_row = add_columns_from_dict(f'{column_name}.{key}', column_value_dict[key], new_row)
        else:
            new_row[f'{column_name}.{key}'] = value
    return new_row

result = []

for _, product in products_df.iterrows():
    index = 0
    for row in product['products.product']:
        index += 1
        new_row = {'_regNum': product['_regNum'], 'inner_index': index}
        
        for column in row:
            if isinstance(row[column], dict):
                new_row = add_columns_from_dict(column, row[column], new_row)
            else:
                new_row[column] = row[column]
        result.append(new_row)
        
result_df = pd.DataFrame(result)
result_df
# Out:
#                     _regNum  inner_index        sid  \
# 0       2021900165421000103            1  321050579
# 1       2021900165421000103            2  321050580
# ...                     ...          ...        ...
# 134478  2430300136021000113            4  338120281
# 134479  2430300136021000113            5  338120282
#
#                                  externalSid  \
# 0                                 5107813837
# 1                                 5107813838
# ...                                      ...
# 134478  429A3899-D982-42F7-962F-0AB17A33ADF3
# 134479  BEC9C1EB-6043-4B22-B34F-7498DDE1626D
#
#                                     guid indexNum              KTRU.code  \
# 0       FC61F0C7C56444569164B36033E6B308        1  32.50.50.190-00002140
# 1       A21038328734429CBF92A54A7DA00103        2  32.50.50.190-00001131
# ...                                  ...      ...                    ...
# 134478  40405D930444483992CDF9C5F82932C8        4                    NaN
# 134479  3FEA9CA48BF54860ADA27BE030299D8B        5                    NaN
#
#                                                 KTRU.name KTRU.versionId  \
# 0         Маска хирургическая, одноразового использования         123368
# 1       Простыня хирургическая общего назначения, одно...          79076
# ...                                                   ...            ...
# 134478                                                NaN            NaN
# 134479                                                NaN            NaN
#
#        KTRU.versionNumber  \
# 0                       2
# 1                       1
# ...                   ...
# 134478                NaN
# 134479                NaN
#
#        KTRU.characteristics.characteristicsUsingReferenceInfo KTRU.OKPD2.code  \
# 0       [{'name': 'Исполнение', 'type': '1', 'kind': '...        32.50.50.190
# 1                                                     NaN        32.50.50.190
# ...                                                   ...                 ...
# 134478                                                NaN                 NaN
# 134479                                                NaN                 NaN
#
#                                           KTRU.OKPD2.name  \
# 0       Изделия медицинские, в том числе хирургические...
# 1       Изделия медицинские, в том числе хирургические...
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#                                                    name hierarchyType  \
# 0               Маска 3-х слойная с фиксатором для носа            ND
# 1       Простыня хирургическая, 200*140см, нестерильная            ND
# ...                                                 ...           ...
# 134478                                       Респиратор            ND
# 134479                               Бахилы медицинские            ND
#
#            type OKEI.code OKEI.nationalCode OKEI.trueNationalCode  \
# 0       PRODUCT       796                ШТ                    ШТ
# 1       PRODUCT       796                ШТ                    ШТ
# ...         ...       ...               ...                   ...
# 134478  PRODUCT       796                ШТ                    ШТ
# 134479  PRODUCT       796                ШТ                    ШТ
#
#        OKEI.fullName OKEI.nationalName           price        priceRUR  \
# 0              Штука                шт   4.15000000000   4.15000000000
# 1              Штука                шт  43.55000000000  43.55000000000
# ...              ...               ...             ...             ...
# 134478         Штука                шт  58.00000000000  58.00000000000
# 134479         Штука                шт  28.00000000000  28.00000000000
#
#        quantity        sum     sumRUR VATRate  \
# 0         50000  207500.00  207500.00       n
# 1          1200   52260.00   52260.00       n
# ...         ...        ...        ...     ...
# 134478     3000  174000.00  174000.00       n
# 134479     3000   84000.00   84000.00       n
#
#                                             originCountry isMedicalProduct  \
# 0       [{'countryCode': '643', 'countryFullName': 'Ро...             true
# 1       [{'countryCode': '643', 'countryFullName': 'Ро...             true
# ...                                                   ...              ...
# 134478  [{'countryCode': '643', 'countryFullName': 'Ро...              NaN
# 134479  [{'countryCode': '643', 'countryFullName': 'Ро...              NaN
#
#        medicalProductInfo.medicalProductCode  \
# 0                                     182450
# 1                                     260270
# ...                                      ...
# 134478                                   NaN
# 134479                                   NaN
#
#                     medicalProductInfo.medicalProductName    OKPD2.code  \
# 0         Маска хирургическая, одноразового использования           NaN
# 1       Простыня хирургическая для пациента, одноразов...           NaN
# ...                                                   ...           ...
# 134478                                                NaN  32.99.11.120
# 134479                                                NaN  15.20.11.129
#
#                                                OKPD2.name  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                        Респираторы
# 134479  Обувь из полимерных материалов прочая, не вклю...
#
#        purchaseObjectExternalSid KTRUNotUsingReason.code  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# ...                          ...                     ...
# 134478                       NaN                     NaN
# 134479                       NaN                     NaN
#
#        KTRUNotUsingReason.name  \
# 0                          NaN
# 1                          NaN
# ...                        ...
# 134478                     NaN
# 134479                     NaN
#
#        KTRU.characteristics.characteristicsUsingTextForm purchaseObjectSid  \
# 0                                                    NaN               NaN
# 1                                                    NaN               NaN
# ...                                                  ...               ...
# 134478                                               NaN               NaN
# 134479                                               NaN               NaN
#
#        KTRUNotUsingReason.anotherKTRUNotUsingReason  \
# 0                                               NaN
# 1                                               NaN
# ...                                             ...
# 134478                                          NaN
# 134479                                          NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.MNNExternalCode  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.MNNDrugCode  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.MNNName  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.dosageUser.dosageUserOKEI.code  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.dosageUser.dosageUserOKEI.fullName  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.dosageUser.dosageUserName  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.positionsTradeName.positionTradeName  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.isZNVLP  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        volumeTextForm
# 0                 NaN
# 1                 NaN
# ...               ...
# 134478            NaN
# 134479            NaN
#
# [134480 rows x 48 columns]
