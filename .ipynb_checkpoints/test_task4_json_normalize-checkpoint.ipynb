# %%
import pandas as pd

df = pd.read_pickle('contracts_data.pkl')
pd.set_option('display.max_columns', 205)
pd.set_option('display.max_rows', 5)
# df = df[0:10]
df.head(5)
# Out:
#   @schemeVersion        id                  externalId        placementDate  \
# 0           11.2  66853167  krista.02800000.5107607098  2021-07-26T15:37:31
# 1           11.2  66905295                         NaN  2021-07-29T11:06:04
# 2           11.1  66049684                         NaN                  NaN
# 3           11.0  62427663                         NaN                  NaN
# 4           11.2  67669379                         NaN  2021-09-17T03:58:54
#
#                      publishDate versionNumber  \
# 0  2021-07-26T17:37:31.373+05:00             0
# 1  2021-07-29T11:06:04.793+03:00             0
# 2  2021-06-10T10:37:47.965+09:00             0
# 3  2021-01-11T15:17:56.329+07:00             0
# 4  2021-09-17T07:58:54.800+07:00             0
#
#   foundation.fcsOrder.order.notificationNumber  \
# 0                          0301300003721000014
# 1                          0126200000421002660
# 2                          0123200000321001246
# 3                          0817200000320016018
# 4                                          NaN
#
#   foundation.fcsOrder.order.lotNumber foundation.fcsOrder.order.placing  \
# 0                                   1                             12011
# 1                                   1                             12011
# 2                                   1                             12011
# 3                                   1                             12011
# 4                                 NaN                               NaN
#
#   foundation.fcsOrder.order.singleCustomer.reason.code  \
# 0                                              20270
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   foundation.fcsOrder.order.singleCustomer.reason.name  \
# 0  Закупка вследствие признания несостоявшимся эл...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   foundation.fcsOrder.order.purchaseCode  \
# 0   212021900165402190100107410013250244
# 1   212312344801331230100101230013250000
# 2   212280103214228010100101140013250244
# 3   202222202955822220100104470013250000
# 4                                    NaN
#
#   foundation.fcsOrder.order.contractProjectNumber  \
# 0                         03013000037210000140001
# 1                         01262000004210026600012
# 2                         01232000003210012460001
# 3                         08172000003200160180002
# 4                                             NaN
#
#   foundation.fcsOrder.order.tenderPlan2020Info.plan2020Number  \
# 0                                 202103013000037001
# 1                                 202103265000006001
# 2                                 202103232000153001
# 3                                 202003172000115001
# 4                                                NaN
#
#   foundation.fcsOrder.order.tenderPlan2020Info.position2020Number  \
# 0                           202103013000037001000030
# 1                           202103265000006001000120
# 2                           202103232000153001000114
# 3                           202003172000115001000452
# 4                                                NaN
#
#   conclusionContractSt95Ch17_1 customer.regNum customer.consRegistryNum  \
# 0                        false     03013000037                 802Р4171
# 1                        false     03265000006                 142В5835
# 2                        false     03232000153                 10202937
# 3                        false     03172000115                 012U8285
# 4                        false     03172000469                 012U7982
#
#                                    customer.fullName  \
# 0  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ЗДРАВООХР...
# 1  ОБЛАСТНОЕ ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ...
# 2  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ЗДРАВООХР...
# 3  КРАЕВОЕ ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ З...
# 4  КРАЕВОЕ ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ З...
#
#                                   customer.shortName  \
# 0                        ГБУЗ РБ КРАСНОУСОЛЬСКАЯ ЦРБ
# 1         ОГБУЗ "ГОРОДСКАЯ ПОЛИКЛИНИКА Г. БЕЛГОРОДА"
# 2  ГБУЗ "АМУРСКИЙ ОБЛАСТНОЙ ПРОТИВОТУБЕРКУЛЕЗНЫЙ ...
# 3                     КГБУЗ "АККПБ ИМ. ЭРДМАНА Ю.К."
# 4  КГБУЗ "АЛТАЙСКИЙ КРАЕВОЙ ГОСПИТАЛЬ ДЛЯ ВЕТЕРАН...
#
#   customer.registrationDate customer.inn customer.kpp customer.legalForm.code  \
# 0                2013-01-01   0219001654    021901001                   75203
# 1                2018-12-27   3123448013    312301001                   75203
# 2                1995-08-23   2801032142    280101001                   75203
# 3                2000-09-04   2222029558    222201001                   75203
# 4                1999-12-30   2225007136    222501001                   75203
#
#                      customer.legalForm.singularName customer.OKPO  \
# 0  Государственное бюджетное учреждение субъекта ...      01952719
# 1  Государственное бюджетное учреждение субъекта ...      35291985
# 2  Государственные бюджетные учреждения субъектов...      01916244
# 3  Государственные бюджетные учреждения субъектов...      54569297
# 4  Государственное бюджетное учреждение субъекта ...      01911368
#
#   customer.customerCode placer.responsibleOrg.regNum  \
# 0  20219001654021901001                  03013000037
# 1  23123448013312301001                  03265000006
# 2  22801032142280101001                  03232000153
# 3  22222029558222201001                  03172000115
# 4  22225007136222501001                  03172000469
#
#   placer.responsibleOrg.consRegistryNum  \
# 0                              802Р4171
# 1                              142В5835
# 2                              10202937
# 3                              012U8285
# 4                              012U7982
#
#                       placer.responsibleOrg.fullName placer.responsibleRole  \
# 0  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ЗДРАВООХР...                     CU
# 1  ОБЛАСТНОЕ ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ...                     CU
# 2  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ЗДРАВООХР...                     CU
# 3  КРАЕВОЕ ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ З...                     CU
# 4  КРАЕВОЕ ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ З...                     CU
#
#   finances.extrabudgetFunds.extrabudget.code  \
# 0                                         60
# 1                                         60
# 2                                         60
# 3                                         60
# 4                                         60
#
#   finances.extrabudgetFunds.extrabudget.name  \
# 0              Средства бюджетных учреждений
# 1              Средства бюджетных учреждений
# 2              Средства бюджетных учреждений
# 3              Средства бюджетных учреждений
# 4              Средства бюджетных учреждений
#
#                     finances.extrabudgetFunds.stages protocolDate  \
# 0  [{'externalSid': '5107931650', 'guid': 'B52BA0...   2021-02-18
# 1  [{'externalSid': '1b4aee66-80b9-4bd7-b40c-97c1...   2021-07-09
# 2  [{'externalSid': '5b1db352-add9-4ee1-8652-c020...   2021-05-27
# 3  [{'guid': '287A2CE2A62444BDA901E04DB249E6D4', ...   2020-12-23
# 4  [{'guid': '83FF1E0DF30A40E4B84940EF819EED0C', ...          NaN
#
#                                             mentBase    signDate  \
# 0  Протокол рассмотрения заявки единственного уча...  2021-03-01
# 1  Итоговый протокол № 0126200000421002660-3 от 0...  2021-07-28
# 2  Протокол подведения итогов электронного аукцио...  2021-06-07
# 3  Протокол подведения итогов электронного аукцио...  2021-01-11
# 4                                                NaN  2021-09-16
#
#           number                                    contractSubject  \
# 0        25/2021  Поставка белья для нужд ГБУЗ РБ Красноусольска...
# 1  Ф.2021.002660  Поставка медицинских изделий для стерилизацион...
# 2        М-37/21           Поставка изделия медицинского назначения
# 3   Э.2020.16018  Поставка медицинских изделий (Изделия для лабо...
# 4            203  ПОСТАВКА РЕАГЕНТОВ И РАСХОДНЫХ МАТЕРИАЛОВ ДЛЯ ...
#
#   isOptimyStart  bankSupportContractRequiredInfo priceInfo.price  \
# 0          true                              NaN       347022.00
# 1          true                              NaN      1448950.00
# 2          true                              NaN        13634.77
# 3           NaN                              NaN         7948.44
# 4          true                              NaN       511918.50
#
#   priceInfo.priceType priceInfo.currency.code priceInfo.currency.name  \
# 0                   P                     RUB        Российский рубль
# 1                  MP                     RUB        Российский рубль
# 2                   P                     RUB        Российский рубль
# 3                   P                     RUB        Российский рубль
# 4                   P                     RUB        Российский рубль
#
#   priceInfo.currencyRate.rate priceInfo.currencyRate.raiting  \
# 0                           1                              1
# 1                           1                              1
# 2                           1                              1
# 3                           1                              1
# 4                           1                              1
#
#   priceInfo.priceRUR priceInfo.priceVAT priceInfo.priceVATRUR  \
# 0          347022.00               0.00                  0.00
# 1         1448950.00               0.00                  0.00
# 2           13634.77               0.00                  0.00
# 3            7948.44             722.59                722.59
# 4          511918.50           46538.04              46538.04
#
#   quantityContractStages executionPeriod.startDate  \
# 0                      1                2021-03-01
# 1                      1                2022-01-01
# 2                      1                2021-06-07
# 3                    NaN                2021-01-11
# 4                    NaN                2021-09-16
#
#                               executionPeriod.stages executionPeriod.endDate  \
# 0  [{'sid': '71222455', 'externalSid': '510793165...              2021-12-31
# 1  [{'sid': '71283136', 'externalSid': '1b4aee66-...              2023-12-31
# 2  [{'sid': '70280345', 'externalSid': '5b1db352-...              2021-08-31
# 3  [{'sid': '65760971', 'guid': '287A2CE2A62444BD...              2022-02-20
# 4  [{'sid': '72195152', 'guid': '83FF1E0DF30A40E4...              2021-10-19
#
#   enforcement.cashAccount.currency.code enforcement.cashAccount.currency.name  \
# 0                                   RUB                      Российский рубль
# 1                                   RUB                      Российский рубль
# 2                                   RUB                      Российский рубль
# 3                                   RUB                      Российский рубль
# 4                                   NaN                                   NaN
#
#   enforcement.cashAccount.amount enforcement.cashAccount.currencyRate.rate  \
# 0                       17351.10                                         1
# 1                      108671.25                                         1
# 2                        2298.33                                         1
# 3                        1103.95                                         1
# 4                            NaN                                       NaN
#
#   enforcement.cashAccount.currencyRate.raiting  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                          NaN
#
#   enforcement.cashAccount.amountRUR  \
# 0                          17351.10
# 1                         108671.25
# 2                           2298.33
# 3                           1103.95
# 4                               NaN
#
#                                    st14Info.NPAsInfo  \
# 0  [{'NPAInfo': {'code': '1', 'name': 'Участникам...
# 1  [{'NPAInfo': {'code': '1', 'name': 'Участникам...
# 2  [{'NPAInfo': {'code': '1', 'name': 'Участникам...
# 3  [{'NPAInfo': {'code': '1', 'name': 'Участникам...
# 4                                                NaN
#
#                                     products.product  \
# 0  [{'sid': '321050579', 'externalSid': '51078138...
# 1  [{'sid': '321522507', 'externalSid': '81af5eab...
# 2  [{'sid': '312968203', 'externalSid': '9d6e3169...
# 3  [{'sid': '276258048', 'guid': 'E3267FC5535E42A...
# 4  [{'sid': '328292135', 'guid': '8AFAEEA20780452...
#
#   products.quantityUndefined  \
# 0                      false
# 1                       true
# 2                      false
# 3                      false
# 4                      false
#
#                           suppliersInfo.supplierInfo  \
# 0  [{'legalEntityRF': {'EGRULInfo': {'OGRN': '116...
# 1  [{'legalEntityRF': {'EGRULInfo': {'OGRN': '121...
# 2  [{'legalEntityRF': {'EGRULInfo': {'OGRN': '107...
# 3                                                NaN
# 4  [{'legalEntityRF': {'EGRULInfo': {'OGRN': '102...
#
#                                                 href  \
# 0  https://zakupki.gov.ru/epz/contract/contractCa...
# 1  https://zakupki.gov.ru/epz/contract/contractCa...
# 2  https://zakupki.gov.ru/epz/contract/contractCa...
# 3  https://zakupki.gov.ru/epz/contract/contractCa...
# 4  https://zakupki.gov.ru/epz/contract/contractCa...
#
#                                        printForm.url                 egNumber  \
# 0  https://zakupki.gov.ru/epz/contract/printForm/...  20219001654210001030001
# 1  https://zakupki.gov.ru/epz/contract/printForm/...  23123448013210001310001
# 2  https://zakupki.gov.ru/epz/contract/printForm/...  22801032142210001590001
# 3  https://zakupki.gov.ru/epz/contract/printForm/...  22222029558210000060001
# 4  https://zakupki.gov.ru/epz/contract/printForm/...  22225007136210002650001
#
#                             scanDocuments.attachment currentContractStage  \
# 0  [{'publishedContentId': 'C801EBA4D2269451E0533...                    E
# 1  [{'publishedContentId': 'C82E5CC058B3555BE0533...                    E
# 2  [{'publishedContentId': 'C45F1D43D164D83BE0532...                    E
# 3  [{'publishedContentId': 'B7A615E9F0A7FD16E0530...                    E
# 4  [{'publishedContentId': 'CC1725A1D1F8F9F6E0533...                    E
#
#   okpd2okved2 mentCode priceInfo.amountsReducedByTaxes  \
# 0        true      NaN                             NaN
# 1       false   120111                             NaN
# 2       false   120111                            true
# 3       false   120111                             NaN
# 4        true      NaN                             NaN
#
#   qualityGuaranteeInfo.notPublishedOnEIS  \
# 0                                    NaN
# 1                                    NaN
# 2                                   true
# 3                                   true
# 4                                    NaN
#
#   qualityGuaranteeInfo.warrantyReqsText  \
# 0                                   NaN
# 1                                   NaN
# 2                            12 месяцев
# 3                                   нет
# 4                                   NaN
#
#   qualityGuaranteeInfo.isQAEnsuramceRequired region_kod  \
# 0                                        NaN        NaN
# 1                                        NaN        NaN
# 2                                       true         28
# 3                                      false         22
# 4                                        NaN        NaN
#
#   subContractorsSum.sumInPercents subContractorsSum.priceValueRUR  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             0.0                            0.00
# 4                             NaN                             NaN
#
#                                   suppliers.supplier  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [{'legalEntityRF': {'legalForm': {'code': '123...
# 4                                                NaN
#
#   foundation.fcsOrder.singleCustomer.reason.code  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                          20070
#
#       foundation.fcsOrder.singleCustomer.reason.name  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Осуществление закупок товаров, работ, услуг пр...
#
#   foundation.fcsOrder.singleCustomer.attachments.attachment.publishedContentId  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                   CC1732EACC0D2514E05334548D0A6812
#
#   foundation.fcsOrder.singleCustomer.attachments.attachment.fileName  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                обоснование заключения договора.pdf
#
#                         escription                 egNumber  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2                              NaN                      NaN
# 3                              NaN                      NaN
# 4  обоснование заключения договора  22225007136210002650002
#
#   foundation.fcsOrder.singleCustomer.attachments.attachment.url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://zakupki.gov.ru/44fz/filestore/public/1...
#
#   foundation.fcsOrder.singleCustomer.purchaseCode  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4            212222500713622250100103160010000244
#
#   foundation.fcsOrder.singleCustomer.tenderPlan2020Info.plan2020Number  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                 202103172000469001
#
#   foundation.fcsOrder.singleCustomer.tenderPlan2020Info.position2020Number  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                           202103172000469001000327
#
#   qualityGuaranteeInfo.execObligationsGuaranteeInfo.ensuringWay.cashAccount.currency.code  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   qualityGuaranteeInfo.execObligationsGuaranteeInfo.ensuringWay.cashAccount.currency.name  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   qualityGuaranteeInfo.execObligationsGuaranteeInfo.ensuringWay.cashAccount.amount  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   modification.errorCorrection.description  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   modification.attachments.attachment.publishedContentId  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   modification.attachments.attachment.fileName escription egNumber  \
# 0                                          NaN        NaN      NaN
# 1                                          NaN        NaN      NaN
# 2                                          NaN        NaN      NaN
# 3                                          NaN        NaN      NaN
# 4                                          NaN        NaN      NaN
#
#   modification.attachments.attachment.url  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   qualityGuaranteeInfo.providedPeriod.otherPeriodText attachments.attachment  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3                                                NaN                     NaN
# 4                                                NaN                     NaN
#
#   qualityGuaranteeInfo.manufacturerWarrantyReqsText  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   finances.budgetFunds.budget.code finances.budgetFunds.budget.name  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#   finances.budgetFunds.OKTMO.code finances.budgetFunds.OKTMO.name  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
#
#   finances.budgetFunds.budgetLevel finances.budgetFunds.stages  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
#
#   enforcement.bankGuarantee.regNumberNotPublishedOnEIS umberNotPublishedOnEIS  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
#   enforcement.bankGuarantee.currency.code  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   enforcement.bankGuarantee.currency.name  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   enforcement.bankGuarantee.guaranteeAmount  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   enforcement.bankGuarantee.currencyRate.rate  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   enforcement.bankGuarantee.currencyRate.raiting  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   enforcement.bankGuarantee.guaranteeAmountRUR  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   finances.budgetFunds.KVRsChange finances.budgetFunds.fundsBudgetLevel  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
#
#   modification.contractChange.reason.code  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   modification.contractChange.reason.name ment.code ment.name ment.base  \
# 0                                     NaN       NaN       NaN       NaN
# 1                                     NaN       NaN       NaN       NaN
# 2                                     NaN       NaN       NaN       NaN
# 3                                     NaN       NaN       NaN       NaN
# 4                                     NaN       NaN       NaN       NaN
#
#   mentDate contractLifeCycle qualityGuaranteeInfo.providedPeriod.fromDate  \
# 0      NaN               NaN                                          NaN
# 1      NaN               NaN                                          NaN
# 2      NaN               NaN                                          NaN
# 3      NaN               NaN                                          NaN
# 4      NaN               NaN                                          NaN
#
#   qualityGuaranteeInfo.providedPeriod.toDate priceInfo.priceFormula  \
# 0                                        NaN                    NaN
# 1                                        NaN                    NaN
# 2                                        NaN                    NaN
# 3                                        NaN                    NaN
# 4                                        NaN                    NaN
#
#   priceInfo.maxPriceAndPriceFormulaSpecified  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   singleSupplierP25Part1St93Documents.attachment  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   advancePaymentSum.sumInPercents advancePaymentSum.priceValue  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
#
#   advancePaymentSum.priceValueRUR  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#   qualityGuaranteeInfo.execObligationsGuaranteeInfo.ensuringWay.bankGuarantee.regNumberNotPublishedOnEIS  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   umberNotPublishedOnEIS  \
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
#   qualityGuaranteeInfo.execObligationsGuaranteeInfo.ensuringWay.bankGuarantee.currency.code  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   qualityGuaranteeInfo.execObligationsGuaranteeInfo.ensuringWay.bankGuarantee.currency.name  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   qualityGuaranteeInfo.execObligationsGuaranteeInfo.ensuringWay.bankGuarantee.amount  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   qualityGuaranteeInfo.execObligationsGuaranteeInfo.ensuringWay.bankGuarantee.amountRUR  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   finances.budgetFunds.KBKsChange modification.attachments.attachment  \
# 0                             NaN                                 NaN
# 1                             NaN                                 NaN
# 2                             NaN                                 NaN
# 3                             NaN                                 NaN
# 4                             NaN                                 NaN
#
#   ment.code ment.name  \
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#
#   modification.attachments.attachment.cryptoSigns.signature  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   qualityGuaranteeInfo.execObligationsGuaranteeInfo.ensuringWay.bankGuarantee.currencyRate.rate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   qualityGuaranteeInfo.execObligationsGuaranteeInfo.ensuringWay.bankGuarantee.currencyRate.raiting  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   foundation.fcsOrder.singleCustomer.attachments.attachment  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   finances.budgetFunds.targetArticlesChange  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   foundation.fcsOrder.order.tenderPlanInfo.plan2017Number  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   foundation.fcsOrder.order.tenderPlanInfo.position2017Number ments  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#   products.productsChange.changeInfo  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#   bankSupportContractRequiredInfo.bankSupportContractRequired  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   defenseContractNumber isGOZ  \
# 0                   NaN   NaN
# 1                   NaN   NaN
# 2                   NaN   NaN
# 3                   NaN   NaN
# 4                   NaN   NaN
#
#   bankSupportContractRequiredInfo.treasurySupportContractRequired ment.code  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#   ment.name medicalDocuments.attachment.publishedContentId  \
# 0       NaN                                            NaN
# 1       NaN                                            NaN
# 2       NaN                                            NaN
# 3       NaN                                            NaN
# 4       NaN                                            NaN
#
#   medicalDocuments.attachment.fileName escription egNumber  \
# 0                                  NaN        NaN      NaN
# 1                                  NaN        NaN      NaN
# 2                                  NaN        NaN      NaN
# 3                                  NaN        NaN      NaN
# 4                                  NaN        NaN      NaN
#
#   medicalDocuments.attachment.url  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#   foundation.fcsOrder.order.singleCustomer.attachments.attachment.publishedContentId  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   foundation.fcsOrder.order.singleCustomer.attachments.attachment.fileName  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   escription egNumber  \
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
#
#   foundation.fcsOrder.order.singleCustomer.attachments.attachment.url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   subContractorsSum.subContractors.subContractor  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   foundation.fcsOrder.notOosOrder.placing  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   foundation.fcsOrder.notOosOrder.purchaseCode  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   foundation.fcsOrder.notOosOrder.tenderPlan2020Info.plan2020Number  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   foundation.fcsOrder.notOosOrder.tenderPlan2020Info.position2020Number  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   constructionWorksInfo.isConstructionWorks  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   guaranteeReturns.guaranteeReturn.notPublishedOnEIS  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   foundation.oosOrder.order.notificationNumber  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   foundation.oosOrder.order.lotNumber foundation.oosOrder.order.placing  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
#
#   priceInfo.rightToConcludeContractPriceInfo.price  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   priceInfo.rightToConcludeContractPriceInfo.currency.code  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   priceInfo.rightToConcludeContractPriceInfo.currency.name  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   priceInfo.rightToConcludeContractPriceInfo.currencyRate.rate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   priceInfo.rightToConcludeContractPriceInfo.currencyRate.raiting  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   priceInfo.rightToConcludeContractPriceInfo.priceRUR  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   medicalDocuments.attachment ment.code ment.name energyServiceContractInfo  \
# 0                         NaN       NaN       NaN                       NaN
# 1                         NaN       NaN       NaN                       NaN
# 2                         NaN       NaN       NaN                       NaN
# 3                         NaN       NaN       NaN                       NaN
# 4                         NaN       NaN       NaN                       NaN
#
#   foundation.fcsOrder.singleCustomer.tenderPlanInfo.plan2017Number  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   foundation.fcsOrder.singleCustomer.tenderPlanInfo.position2017Number  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   foundation.fcsOrder.order.singleCustomer.attachments.attachment  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   budgetObligations.publishedContentId budgetObligations.fileName escription  \
# 0                                  NaN                        NaN        NaN
# 1                                  NaN                        NaN        NaN
# 2                                  NaN                        NaN        NaN
# 3                                  NaN                        NaN        NaN
# 4                                  NaN                        NaN        NaN
#
#   budgetObligations.url foundation.fcsOrder.order.singleCustomer.reportBase  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
#
#   mentName mentNum mentDate  \
# 0      NaN     NaN      NaN
# 1      NaN     NaN      NaN
# 2      NaN     NaN      NaN
# 3      NaN     NaN      NaN
# 4      NaN     NaN      NaN
#
#   modification.contractChange.damagePayments.currency.code  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   modification.contractChange.damagePayments.currency.name  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   modification.contractChange.damagePayments.amount  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   modification.contractChange.damagePayments.amountRUR  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   medicalDocuments.attachment.cryptoSigns.signature  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   qualityGuaranteeInfo.execObligationsGuaranteeInfo.guaranteeReturns.guaranteeReturn.notPublishedOnEIS  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                _regNum
# 0  2021900165421000103
# 1  2312344801321000131
# 2  2280103214221000159
# 3  2222202955821000006
# 4  2222500713621000265

# %%
products_df = df[['_regNum', 'products.product']]

# %%
result = []
for product_id, product in products_df.iterrows():
    normalized_products = pd.json_normalize(products_df['products.product'][product_id])
    
    normalized_products.insert(0,'inner_index', '')
    
    normalized_products.insert(0,'_regNum', products_df['_regNum'][product_id])
    index = 0
    for _, row in normalized_products.iterrows():
        index += 1
        row['inner_index'] = index
        result.append(row)
        
result_df = pd.DataFrame(result)
result_df = result_df.reset_index(drop=True)
result_df
# Out:
#                     _regNum  inner_index        sid  \
# 0       2021900165421000103            1  321050579
# 1       2021900165421000103            2  321050580
# ...                     ...          ...        ...
# 134478  2430300136021000113            4  338120281
# 134479  2430300136021000113            5  338120282
#
#                                  externalSid  \
# 0                                 5107813837
# 1                                 5107813838
# ...                                      ...
# 134478  429A3899-D982-42F7-962F-0AB17A33ADF3
# 134479  BEC9C1EB-6043-4B22-B34F-7498DDE1626D
#
#                                     guid indexNum  \
# 0       FC61F0C7C56444569164B36033E6B308        1
# 1       A21038328734429CBF92A54A7DA00103        2
# ...                                  ...      ...
# 134478  40405D930444483992CDF9C5F82932C8        4
# 134479  3FEA9CA48BF54860ADA27BE030299D8B        5
#
#                                                    name hierarchyType  \
# 0               Маска 3-х слойная с фиксатором для носа            ND
# 1       Простыня хирургическая, 200*140см, нестерильная            ND
# ...                                                 ...           ...
# 134478                                       Респиратор            ND
# 134479                               Бахилы медицинские            ND
#
#            type           price        priceRUR quantity        sum  \
# 0       PRODUCT   4.15000000000   4.15000000000    50000  207500.00
# 1       PRODUCT  43.55000000000  43.55000000000     1200   52260.00
# ...         ...             ...             ...      ...        ...
# 134478  PRODUCT  58.00000000000  58.00000000000     3000  174000.00
# 134479  PRODUCT  28.00000000000  28.00000000000     3000   84000.00
#
#            sumRUR VATRate                                      originCountry  \
# 0       207500.00       n  [{'countryCode': '643', 'countryFullName': 'Ро...
# 1        52260.00       n  [{'countryCode': '643', 'countryFullName': 'Ро...
# ...           ...     ...                                                ...
# 134478  174000.00       n  [{'countryCode': '643', 'countryFullName': 'Ро...
# 134479   84000.00       n  [{'countryCode': '643', 'countryFullName': 'Ро...
#
#        isMedicalProduct              KTRU.code  \
# 0                  true  32.50.50.190-00002140
# 1                  true  32.50.50.190-00001131
# ...                 ...                    ...
# 134478              NaN                    NaN
# 134479              NaN                    NaN
#
#                                                 KTRU.name KTRU.versionId  \
# 0         Маска хирургическая, одноразового использования         123368
# 1       Простыня хирургическая общего назначения, одно...          79076
# ...                                                   ...            ...
# 134478                                                NaN            NaN
# 134479                                                NaN            NaN
#
#        KTRU.versionNumber  \
# 0                       2
# 1                       1
# ...                   ...
# 134478                NaN
# 134479                NaN
#
#        KTRU.characteristics.characteristicsUsingReferenceInfo KTRU.OKPD2.code  \
# 0       [{'name': 'Исполнение', 'type': '1', 'kind': '...        32.50.50.190
# 1                                                     NaN        32.50.50.190
# ...                                                   ...                 ...
# 134478                                                NaN                 NaN
# 134479                                                NaN                 NaN
#
#                                           KTRU.OKPD2.name OKEI.code  \
# 0       Изделия медицинские, в том числе хирургические...       796
# 1       Изделия медицинские, в том числе хирургические...       796
# ...                                                   ...       ...
# 134478                                                NaN       796
# 134479                                                NaN       796
#
#        OKEI.nationalCode OKEI.trueNationalCode OKEI.fullName  \
# 0                     ШТ                    ШТ         Штука
# 1                     ШТ                    ШТ         Штука
# ...                  ...                   ...           ...
# 134478                ШТ                    ШТ         Штука
# 134479                ШТ                    ШТ         Штука
#
#        OKEI.nationalName medicalProductInfo.medicalProductCode  \
# 0                     шт                                182450
# 1                     шт                                260270
# ...                  ...                                   ...
# 134478                шт                                   NaN
# 134479                шт                                   NaN
#
#                     medicalProductInfo.medicalProductName    OKPD2.code  \
# 0         Маска хирургическая, одноразового использования           NaN
# 1       Простыня хирургическая для пациента, одноразов...           NaN
# ...                                                   ...           ...
# 134478                                                NaN  32.99.11.120
# 134479                                                NaN  15.20.11.129
#
#                                                OKPD2.name  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                        Респираторы
# 134479  Обувь из полимерных материалов прочая, не вклю...
#
#        purchaseObjectExternalSid KTRUNotUsingReason.code  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# ...                          ...                     ...
# 134478                       NaN                     NaN
# 134479                       NaN                     NaN
#
#        KTRUNotUsingReason.name  \
# 0                          NaN
# 1                          NaN
# ...                        ...
# 134478                     NaN
# 134479                     NaN
#
#        KTRU.characteristics.characteristicsUsingTextForm purchaseObjectSid  \
# 0                                                    NaN               NaN
# 1                                                    NaN               NaN
# ...                                                  ...               ...
# 134478                                               NaN               NaN
# 134479                                               NaN               NaN
#
#        KTRUNotUsingReason.anotherKTRUNotUsingReason  \
# 0                                               NaN
# 1                                               NaN
# ...                                             ...
# 134478                                          NaN
# 134479                                          NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.MNNExternalCode  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.MNNDrugCode  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.MNNName  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.dosageUser.dosageUserOKEI.code  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.dosageUser.dosageUserOKEI.fullName  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.dosageUser.dosageUserName  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.positionsTradeName.positionTradeName  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.isZNVLP  \
# 0                                                     NaN
# 1                                                     NaN
# ...                                                   ...
# 134478                                                NaN
# 134479                                                NaN
#
#        volumeTextForm
# 0                 NaN
# 1                 NaN
# ...               ...
# 134478            NaN
# 134479            NaN
#
# [134480 rows x 48 columns]

# %%
result_df.columns
# Out:
# Index(['_regNum', 'inner_index', 'sid', 'externalSid', 'guid', 'indexNum',
#        'name', 'hierarchyType', 'type', 'price', 'priceRUR', 'quantity', 'sum',
#        'sumRUR', 'VATRate', 'originCountry', 'isMedicalProduct', 'KTRU.code',
#        'KTRU.name', 'KTRU.versionId', 'KTRU.versionNumber',
#        'KTRU.characteristics.characteristicsUsingReferenceInfo',
#        'KTRU.OKPD2.code', 'KTRU.OKPD2.name', 'OKEI.code', 'OKEI.nationalCode',
#        'OKEI.trueNationalCode', 'OKEI.fullName', 'OKEI.nationalName',
#        'medicalProductInfo.medicalProductCode',
#        'medicalProductInfo.medicalProductName', 'OKPD2.code', 'OKPD2.name',
#        'index', 'purchaseObjectExternalSid', 'KTRUNotUsingReason.code',
#        'KTRUNotUsingReason.name',
#        'KTRU.characteristics.characteristicsUsingTextForm',
#        'purchaseObjectSid', 'KTRUNotUsingReason.anotherKTRUNotUsingReason',
#        'drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.MNNExternalCode',
#        'drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.MNNDrugCode',
#        'drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.MNNName',
#        'drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.dosageUser.dosageUserOKEI.code',
#        'drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.dosageUser.dosageUserOKEI.fullName',
#        'drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.dosageUser.dosageUserName',
#        'drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.MNNsInfo.MNNInfo.positionsTradeName.positionTradeName',
#        'drugPurchaseObjectInfo.drugInfoUsingReferenceInfo.isZNVLP',
#        'volumeTextForm'],
#       dtype='object')
